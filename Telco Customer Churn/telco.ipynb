# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import chi2_contingency

# %%
data_df = pd.read_csv("telco.csv")

# %%
print(f"shape: {data_df.shape}")
print(f"len: {len(data_df)}")
print(f"size: {data_df.size}")
# Out:
# shape: (7043, 21)
# len: 7043
# size: 147903

# %%
data_df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1595  2761-OCIAX    Male              1      No         No       2
# 4341  3754-DXMRT    Male              1      No         No       2
# 1607  4154-AQUGT    Male              1     Yes         No      13
# 5804  1555-HAPSU  Female              0     Yes        Yes      71
# 1724  7398-SKNQZ  Female              0     Yes         No       3
# 212   7157-SMCFK    Male              0      No        Yes      61
# 4795  6532-YLWSI  Female              0     Yes         No      53
# 6284  2985-FMWYF  Female              0      No         No      23
# 6266  5813-UECBU    Male              1      No         No      33
# 3063  1666-JXLKU  Female              0      No         No      37
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 1595          Yes            No     Fiber optic                   No  ...
# 4341          Yes            No             DSL                   No  ...
# 1607          Yes            No     Fiber optic                   No  ...
# 5804          Yes           Yes              No  No internet service  ...
# 1724          Yes           Yes     Fiber optic                   No  ...
# 212           Yes            No              No  No internet service  ...
# 4795          Yes            No              No  No internet service  ...
# 6284          Yes           Yes     Fiber optic                   No  ...
# 6266          Yes           Yes     Fiber optic                   No  ...
# 3063          Yes           Yes     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 1595                   No                   No                   No
# 4341                   No                   No                   No
# 1607                   No                  Yes                   No
# 5804  No internet service  No internet service  No internet service
# 1724                   No                   No                  Yes
# 212   No internet service  No internet service  No internet service
# 4795  No internet service  No internet service  No internet service
# 6284                   No                   No                  Yes
# 6266                  Yes                   No                   No
# 3063                  Yes                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 1595                   No  Month-to-month              Yes
# 4341                   No  Month-to-month              Yes
# 1607                  Yes  Month-to-month              Yes
# 5804  No internet service        Two year               No
# 1724                  Yes  Month-to-month               No
# 212   No internet service        Two year               No
# 4795  No internet service        One year               No
# 6284                  Yes  Month-to-month              Yes
# 6266                   No  Month-to-month              Yes
# 3063                  Yes  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 1595           Electronic check          74.70         165.4   Yes
# 4341           Electronic check          44.15         92.65   Yes
# 1607  Bank transfer (automatic)          89.05       1169.35   Yes
# 5804    Credit card (automatic)          23.90        1663.5    No
# 1724           Electronic check          94.90         273.2    No
# 212                Mailed check          19.75        1124.2    No
# 4795  Bank transfer (automatic)          20.80        1021.8   Yes
# 6284           Electronic check          93.50       2341.55    No
# 6266    Credit card (automatic)          83.85        2716.3   Yes
# 3063           Electronic check         100.05       3810.55    No
#
# [10 rows x 21 columns]

# %%
data_df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
data_df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64
